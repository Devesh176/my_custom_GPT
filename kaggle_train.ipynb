# %%
# !git clone https://github.com/Devesh176/my_custom_GPT.git
# Out:
# Cloning into 'my_custom_GPT'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 247 (delta 125), reused 190 (delta 77), pack-reused 0 (from 0)
# Receiving objects: 100% (247/247), 3.49 MiB | 22.20 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# %cd my_custom_GPT
# Out:
# /kaggle/working/my_custom_GPT

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cat config.yaml
# Out:
# GPT_CONFIG:
#   ctx_length: 1024
#   device: cuda
#   dropout: 0.1
#   emb_dim: 768
#   ff_hidden_dim: 1024
#   gradient_clip_val: 1.0
#   log_interval: 100
#   loss_function: CrossEntropyLoss
#   model_name: custom_gpt
#   model_type: GPT
#   n_heads: 12
#   n_layers: 12
#   qkv_bias: false
#   save_checkpoint_every: 1000
#   scheduler: CosineAnnealingLR
#   warmup_steps: 1000
#   weight_decay: 0.01
# TRAINING_CONFIG:
#   batch_size: 16
#   eval_freq: 1
#   eval_iter: 1
#   learning_rate: 5e-4
#   loss_function: CrossEntropyLoss
#   num_epochs: 10
#   num_workers: 0
#   optimizer: AdamW
#   train_ratio: 0.8
#   weight_decay: 0.1
# data_load:
#   batch_size: 64
#   block_size: 64
#   max_length: 128
#   num_workers: 0
#   shuffle: true
#   stride: 1
#   token_sequence_size: 256
# project:
#   author: Devesh176
#   description: A custom GPT model for text generation
#   name: my_custom_GPT
#   version: 1.0.0
# tokenizer:
#   embedding_dim: 768
#   token_sequence_size: 256
# ...

# %%
import yaml

# 1. Load the existing file
file_path = "config.yaml"
with open(file_path, 'r') as file:
    yaml_content = yaml.safe_load(file)

# 2. Modify the specific keys you need
yaml_content['TRAINING_CONFIG']['batch_size'] = 16


# 3. Save the changes back to the file
with open(file_path, 'w') as file:
    yaml.dump(yaml_content, file, default_flow_style=False)

# %%
# !python custom_GPT/train.py
# Out:
# Total number of parameters: 124,449,792
# Starting the Epochs 10
# Training batches from train_loader
# finished the batches from train_loader
# Evaluating the model
# Epoch [1/10], Train Loss: 0.0892, Val Loss: 8.3041
# GPU synchronized
# Generating sample
# Every effort moves you can just manage to see it. I had it over the solace of her absurdity he seemed to be wincing under--his own attitude as an object for garlands and incense.  "My dear, since I've chucked painting
# Training batches from train_loader
# finished the batches from train_loader
# Evaluating the model
# Epoch [2/10], Train Loss: 0.0816, Val Loss: 8.7016
# GPU synchronized
# Generating sample
# Every effort moves you in a hooded chair, had lit a cigar and drawn the Russian deerhound's head between his knees.   "Well, come while he's not looking," she said, with a laugh that tried to hide her nervousness; and
# Training batches from train_loader
# finished the batches from train_loader
# Evaluating the model
# ...
